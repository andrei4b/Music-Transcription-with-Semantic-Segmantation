# %% [markdown]
# ## Initialize

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pwd
# %cd drive/My\ Drive
# Out:
# /content
# /content/drive/My Drive

# %%
# !git clone https://github.com/andrei4b/Music-Transcription-with-Semantic-Segmantation.git
# Out:
# Cloning into 'Music-Transcription-with-Semantic-Segmantation'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 232 (delta 3), reused 11 (delta 3), pack-reused 220
# Receiving objects: 100% (232/232), 225.06 MiB | 21.85 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# Checking out files: 100% (45/45), done.

# %%
# !mv maestro/ Music-Transcription-with-Semantic-Segmantation/MAESTRO/

# %%
# !ls
# Out:
# 'AMT with SS.ipynb'		 contacts.vcf
# 'AMT with SS on MAESTRO.ipynb'	 Music-Transcription-with-Semantic-Segmantation

# %% [markdown]
# ##Train

# %%
# !python Music-Transcription-with-Semantic-Segmantation/TrainSemanticModel.py --help

# %%
# !python Music-Transcription-with-Semantic-Segmantation/TrainSemanticModel.py --MAPS-feature-path Music-Transcription-with-Semantic-Segmantation/MAESTRO/maestro/features/train -nd 7 -b 8
# Out:
# Using TensorFlow backend.
#
#  Namespace(MAPS_feature_path='Music-Transcription-with-Semantic-Segmantation/MAESTRO/maestro/features/train', MusicNet_feature_path=None, batch_size_train=8, channels=[1, 3], epoch=5, input_model=None, model_path_symbolic='model_symbolic', model_type='seg', mpe_only=False, no_harmonic=False, num_datasets=7, output_model_name='onsets_model_ + <list_of_channel_used>', steps=6000, use_ram=False, window_width=128)
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-05-28 09:53:03.706728: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# ...

# %%
# !tensorboard --logdir=./tensorboard
# Out:
# TensorBoard 1.13.1 at http://f821c5203021:6006 (Press CTRL+C to quit)
# W0528 20:57:48.260590 140250216580864 plugin_event_accumulator.py:294] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# ^C

# %% [markdown]
# ## Predict

# %%
# !python3 Music-Transcription-with-Semantic-Segmantation/Predict.py --help

# %%
# !python3 Music-Transcription-with-Semantic-Segmantation/Predict.py --model-path model/maestro2017_model --test-path Music-Transcription-with-Semantic-Segmantation/MAESTRO/maestro/features/test/ --label-path Music-Transcription-with-Semantic-Segmantation/MAESTRO/maestro/features/test/
# Out:
# Fragments:   1% 2/194 [00:00<00:16, 11.50it/s]
#
# Fragments:   2% 4/194 [00:00<00:15, 11.93it/s]
#
# Fragments:   3% 6/194 [00:00<00:14, 12.75it/s]
#
# Fragments:   4% 8/194 [00:00<00:13, 13.47it/s]
#
# Fragments:   5% 10/194 [00:00<00:13, 14.04it/s]
#
# Fragments:   6% 12/194 [00:00<00:12, 14.38it/s]
#
# Fragments:   7% 14/194 [00:00<00:12, 14.37it/s]
#
# Fragments:   8% 16/194 [00:01<00:12, 14.61it/s]
#
# Fragments:   9% 18/194 [00:01<00:11, 14.82it/s]
#
# Fragments:  10% 20/194 [00:01<00:11, 15.01it/s]
#
# Fragments:  11% 22/194 [00:01<00:11, 15.08it/s]
#
# Fragments:  12% 24/194 [00:01<00:11, 15.16it/s]
#
# Fragments:  13% 26/194 [00:01<00:11, 15.24it/s]
#
# Fragments:  14% 28/194 [00:01<00:10, 15.21it/s]
#
# Fragments:  15% 30/194 [00:02<00:10, 15.20it/s]
#
# Fragments:  16% 32/194 [00:02<00:10, 15.19it/s]
#
# Fragments:  18% 34/194 [00:02<00:10, 15.26it/s]
#
# Fragments:  19% 36/194 [00:02<00:10, 15.34it/s]
#
# Fragments:  20% 38/194 [00:02<00:10, 15.31it/s]
#
# ...

# %% [markdown]
# ## Evaluate

# %%
# !python3 Music-Transcription-with-Semantic-Segmantation/Evaluation.py --help
# Out:
# usage: Evaluation.py [-h] [--val-pred-path VAL_PRED_PATH]
#                      [--test-pred-path TEST_PRED_PATH]
#                      [--spec-instrument SPEC_INSTRUMENT] [--merge-channels]
#
# Evaluate on the predictions
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --val-pred-path VAL_PRED_PATH
#                         Path to directory of prediction files of validation
#                         set. If not given, the threshold used during the
#                         evaluation will be directly set based on the test set.
#   --test-pred-path TEST_PRED_PATH
#                         Path to directory of prediction files of test set.
#   --spec-instrument SPEC_INSTRUMENT
#                         To evaluate on the specific channel. This option is
#                         for MusicNet. (default 0)
#   --merge-channels      Merge channels into single channel. Keep the maximum
# ...

# %%
# !python3 Music-Transcription-with-Semantic-Segmantation/Evaluation.py --test-pred-path predictions/maestro2017_model
# Out:
# Loading testing predictions:  predictions/maestro2017_model
# (1/60)
# /usr/local/lib/python3.6/dist-packages/mir_eval/multipitch.py:410: UserWarning: Estimate times not equal to reference times. Resampling to common time base.
#   warnings.warn("Estimate times not equal to reference times. "
# (2/60)
# (3/60)
# (4/60)
# (5/60)
# (6/60)
# (7/60)
# (8/60)
# (9/60)
# (10/60)
# (11/60)
# (12/60)
# (13/60)
# (14/60)
# (15/60)
# (16/60)
# (17/60)
# (18/60)
# (19/60)
# (20/60)
# (21/60)
# (22/60)
# (23/60)
# (24/60)
# (25/60)
# (26/60)
# (27/60)
# (28/60)
# (29/60)
# (30/60)
# (31/60)
# (32/60)
# (33/60)
# (34/60)
# (35/60)
# (36/60)
# (37/60)
# (38/60)
# (39/60)
# (40/60)
# (41/60)
# (42/60)
# (43/60)
# (44/60)
# (45/60)
# (46/60)
# (47/60)
# (48/60)
# (49/60)
# (50/60)
# (51/60)
# (52/60)
# (53/60)
# (54/60)
# (55/60)
# (56/60)
# (57/60)
# (58/60)
# (59/60)
# (60/60)
#
# Total average:
# Prec: 0.7679 Rec: 0.7767 Acc: 0.6285 F-score: 0.7699

# %% [markdown]
# ## Print Piano Roll

# %%
# !python3 Music-Transcription-with-Semantic-Segmantation/PrintPianoRoll.py --help

# %%
# !python3 Music-Transcription-with-Semantic-Segmantation/PrintPianoRoll.py -p predictions/onsets_model_\[1,\ 3\] -q -t 0.39 -i 0
